# %%
from sqlalchemy import create_engine

database="sampledb"
hostname="barista2.mysql.database.azure.com"
username="barista_admin"
password="ilovecoffee123!"

# Connect to the database
engine = create_engine(f"mysql+mysqlconnector://{username}:{password}@{hostname}/{database}")

# Test the connection
connection = engine.connect()

# %%
# Creating the database table from the provided XLS file
import pandas as pd

df = pd.read_excel('SampleSuperstore.xls')
df.head()

#df.to_sql('samplesuperstore', engine)
# Out:
# /var/folders/sl/fgdt3jf15xd619t9skb1vv2m0000gn/T/ipykernel_29223/803303726.py:6: UserWarning: The provided table name 'SampleSuperstore' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql('SampleSuperstore', engine)
# -1

# %%
# Displaying results from the database 
import mysql.connector as conn

try:
    mydb = conn.connect(host=hostname, database=database, user=username, passwd=password, use_pure=True)
    query = "SELECT * FROM samplesuperstore;"
    df = pd.read_sql(query, mydb)
    mydb.close() #close the connection
except Exception as e:
    mydb.close()
    print(str(e))
    

df.head()
# Out:
# /var/folders/sl/fgdt3jf15xd619t9skb1vv2m0000gn/T/ipykernel_29223/2331926858.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, mydb)
#    index  Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0      0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1      1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2      2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3      3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4      4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
#
#   Customer ID    Customer Name    Segment        Country  ... Postal Code  \
# 0    CG-12520      Claire Gute   Consumer  United States  ...       42420
# 1    CG-12520      Claire Gute   Consumer  United States  ...       42420
# ...
